# %% [markdown]
# Financial investment decision is a function of risk and return, which are positively related to each other. Investor tries to obtain highest possible return while mitigating the risk as much as possible. So, in a nutshell, investor tend to invest in an asset with best risk-return combination. But the question is how can we estimate the best risk-return combination?

# %% [markdown]
# This lesson tries to tackle this question using two celebrated models. In this part of the lesson, we will discuss the two prominent models about asset valuation:
# * Capital Asset Pricing Model
# * Arbitrage Pricing Theorem

# %% [markdown]
# ## Capital Asset Pricing Model (CAPM)

# %% [markdown]
# It is an easy task to measure return of an asset, which is nothing but a change in an asset's value based on previous period. How about risk? It is exactly where `Markowitz's Portfolio Theory`comes into the picture. Markowitz's article titled ["Portfolio Selection"](https://www.math.ust.hk/~maykwok/courses/ma362/07F/markowitz_JF.pdf) provides a clear definition of what had hitherto been unambiguous.

# %% [markdown]
# This trade-off is defined as the selection problem of the portfolio mean and variance of the assets, and given the risk level the theory has suggested that high expected return should be selected. Expected return and risk are given as follows:

# %% [markdown]
# $$ \text{Expected Return}=\mathbb{E}(R_i)$$
# $$\text{Risk}=\sigma (R_i)$$

# %% [markdown]
# where $R_i$ is the return of ith asset and $\mathbb{E}$ denotes expectation operator, and $\sigma$ represents the standard deviation of return. Thus, standard deviation is assumed to be a risk of an asset and this approach paves the way for further analysis.

# %% [markdown]
# Starting with Markowitz's contribution, risk-return relationship of an asset is well-founded as new approaches emerges. Of these approaches. Capital Asset Pricing Model is the one of the most prominents one.

# %% [markdown]
# The CAPM is based on the idea that the individual investor can make a combination between the borrower portfolios and the lender portfolios, to organize his own risk and to create an optimal portfolio among the risky assets. CAPM, suggested by [Sharpe (1964)](http://efinance.org.cn/cn/fm/Capital%20Asset%20Prices%20A%20Theory%20of%20Market%20Equilibrium%20under%20Conditions%20of%20Risk.pdf), [Lintner (1965)](http://www.empirical.net/wp-content/uploads/2014/12/Lintner-The-Valuation-of-Risk-Assets-and-the-Selection-of-Risky-Investments-in-Stock-Portfolios-and-Capital-Budgets.pdf), and [Black (1972)](http://www.stat.ucla.edu/~nchristo/statistics_c183_c283/fischer_black_trace_out.pdf) , is a model investigating the systematic risk and return in a competitive market.

# %% [markdown]
# As we have discussed, the primary motivation of an investor in forming a best risk-return portfolio is to mitigate the risk while having highest return but it is not possible to make all risks go away. That is to say, there are some risks that an investor can mitigate and some he/she cannot. By diversification, which is simply forming a portfolio with assets having high risk-return relationship and with assets having low risk-return relationship, the risk can be reduced to certain level. But what is this level?

# %% [markdown]
# In order to better understand and handle the risk in finance, we need to differentiate it:
# * Systematic Risk: It is the that cannot be disappeared by diversification. Therefore it is also referred to as `non-diversifiable risk`.  More specifically, random fluctuations in the value of an asset can be balanced out by holding diverse assets. Some systematic risks are:
#     * Interest rate risk
#     * Inflation risk
#     * Market risk

# %% [markdown]
# * Unsystematic Risk: It is the risk that can be mitigated through diversification. That is random fluctuations in the value of the asset can be balanced out by holding many different assets. Unsystematic risk arises from Stock-specific issues. Some unsystematic risks can be listed as:
#     * Business risk: Any Internal weakness of a company can jeopardize its profitability
#     * Financial risk: Change in capital structure allocation of a company
#     * Entrance of a new competitor

# %% [markdown]
# CAPM examines the systematic risk ($\beta$) and expected return in a competitive market. It is a parametric and univariate approach. The ultimate aim of this method is to price an individual security or a portfolio. Let's now talk about the components and the formula of CAPM:

# %% [markdown]
# $$\mathbb{E}(R_i)=\alpha_i+\beta_i\mathbb{E}(R_m)$$

# %% [markdown]
# where
#  * $R_i$: Expected excess return of the $i^{th}$ stock
#  * $\alpha_i$: asset’s return\loss coming from technical analysis
#  * $R_m$: Expected excess market return
#  * $\beta_{i}$: Slope coefficient

# %% [markdown]
# Here, excess return represents the portion of an individual stock or market return above the `risk free rate`. Or it can be formulated as:

# %% [markdown]
# $$\mathbb{E}(R_i)=\mathbb{E}(r_i)-r_f$$

# %% [markdown]
# where $r_f$ is risk free rate and $r_i$ is the individual stock return. So, excess return checks if an asset yields  larger return than a safe asset. If so, it is a motivation to invest, otherwise, investor prefer to invest in a safe asset whose return is low but guaranteed.

# %% [markdown]
# The result, denoted as $\mathbb{E}(R_i)$, is also the required return or discount rate used in valuing an asset or a project that we discuss in NPV lesson:

# %% [markdown]
# Required Rate of Return = Risk Free Rate of Return + Beta*(Market Return – Risk Free Rate of Return)

# %% [markdown]
# We need to put special emphasize on $\beta$, which shows the extent to which an investment adds risk to a portfolio. Put differently, it is a measure of systematic risk of a stock in comparison to the market. It is also indicates the correlation between individual stock and market:

# %% [markdown]
# * If the $\beta$>1, stock is riskier than the benchmark market
# * If the $\beta$=1, stock is as riskier as the benchmark market
# * If the $\beta$<1, stock is as less riskier as than the benchmark market

# %% [markdown]
# Hence, beta coefficient indicates the ratio between the covariance of individual stock return and market return and the stock market return variance:

# %% [markdown]
# $$\beta_i = \frac{\text{Cov}(r_i, r_m)}{\text{Var}(r_m)}$$

# %% [markdown]
# In econometrical approach, CAPM can be defined as:

# %% [markdown]
# $$
# \mathbb{E}(r_i)-r_f= \alpha_i + \beta_{i}(\mathbb{E}(r_m)-r_f) + \epsilon_i
# $$

# %% [markdown]
# where
#  * $\epsilon_i$: Error term

# %% [markdown]
# As a final note for this theoretical discussion, I would like to name a few pros and cons of CAPM approach:

# %% [markdown]
# **Pros**

# %% [markdown]
# * Ease of use
#
# * Diversified Portfolio: The assumption that investors have a diversified portfolio similar to the market portfolio eliminates the non-systematic (specific) risk.
#
# * CAPM takes into account systematic risk
#
# * CAPM can be used as a model to account for the business and financial Risk variability

# %% [markdown]
# **Cons**

# %% [markdown]
# * The proxy used for risk free rate  is subject to change and open to discussion.
# * A risk-free borrowing capability is far from being realistic
# * Using CAPM to evaluate an investment must find a suitable beta for the project or investment to correctly evaluate it.

# %% [markdown]
# In this part, instead of visiting a website and downloading the data to our local computer, we directly access to `yahoo finance` and retrieve the data as  we have learned in the previous lesson. To compare the performance of the companies, we will run CAPM analyses with three difference companies operating in telecomunication sector. These companies are `Apple`, `IBM`,`Microsoft`, `Intel` and the market these stocks are listed is `S&P-500`. We use tickers to retreive data from yahoo finance:
#
#  * AAPL: Apple
#  * IBM: IBM
#  * MSFT: Microsoft
#  * INTC: Intel
#  * ^GSPC: S&P-500

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns
import warnings
import yfinance as yf
import seaborn as sns; sns.set()
yf.pdr_override() 
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# The analysis covers the business day for the period of 01-01-2021 and 04-01-2021 with monthly stock price data.

# %%
stocks = ['AAPL','IBM','MSFT','INTC','^GSPC']
start = datetime.datetime(2021,1,1)
end = datetime.datetime(2021,4,1)
stock_prices = yf.download(stocks,start=start,end = end, interval='1d')
# Out:
# [*********************100%***********************]  5 of 5 downloaded

# %%
stock_prices.head()
# Out:
#            Adj Close                                   Close                 \
#                 AAPL     IBM   INTC    MSFT    ^GSPC    AAPL     IBM   INTC
# Date
# 2020-12-31    132.27  122.85  49.22  221.91  3756.07  132.69  125.88  49.82
# 2021-01-04    129.00  120.95  49.07  217.19  3700.65  129.41  123.94  49.67
# 2021-01-05    130.59  123.10  50.00  217.40  3726.86  131.01  126.14  50.61
# 2021-01-06    126.20  126.18  50.48  211.76  3748.14  126.60  129.29  51.10
# 2021-01-07    130.50  125.88  51.56  217.79  3803.79  130.92  128.99  52.19
#
#                              ...    Open                                  \
#               MSFT    ^GSPC  ...    AAPL     IBM   INTC    MSFT    ^GSPC
# Date                         ...
# 2020-12-31  222.42  3756.07  ...  134.08  124.22  48.75  221.70  3733.27
# 2021-01-04  217.69  3700.65  ...  133.52  125.85  49.89  222.53  3764.61
# 2021-01-05  217.90  3726.86  ...  128.89  125.01  49.45  217.26  3698.02
# 2021-01-06  212.25  3748.14  ...  127.72  126.90  50.44  212.17  3712.20
# 2021-01-07  218.29  3803.79  ...  128.36  130.04  51.49  214.04  3764.71
#
#                Volume
#                  AAPL      IBM      INTC      MSFT       ^GSPC
# Date
# 2020-12-31   99116600  3574400  28576800  20942100  3172510000
# 2021-01-04  143301900  5179200  46102500  37130100  5006680000
# 2021-01-05   97664900  6114600  24866600  23823000  4582620000
# 2021-01-06  155088000  7956700  36809600  35930700  6049970000
# 2021-01-07  109578200  4507400  32092300  27694500  5080870000
#
# [5 rows x 30 columns]

# %%
stock_prices=stock_prices['Close']

# %%
stock_prices.dropna(inplace=True)

# %% [markdown]
# Summary statistics is a very first step to explore the dataset. Main statistics such as mean, standard deviation, minimum, maximum etc., can be calculated via `.describe()` in Python. Initial observation tells us that the price level and volatility (represented by standard deviation) of S&P-500 is quite different from the rest of the stocks.

# %%
stock_prices.describe()
# Out:
#              AAPL         IBM       INTC        MSFT        ^GSPC
# count   62.000000   62.000000  62.000000   62.000000    62.000000
# mean   128.427903  125.195968  59.438226  231.866613  3863.938548
# std      6.726222    4.862788   4.248762    9.164177    71.994504
# min    116.360000  118.580000  49.670000  212.250000  3700.650000
# 25%    121.985000  120.755000  57.107500  226.895000  3810.167500
# 50%    128.315000  124.060000  60.530000  233.525000  3873.590000
# 75%    133.752500  128.985000  62.827500  237.677500  3915.557500
# max    143.160000  136.380000  65.780000  244.990000  3974.540000

# %% [markdown]
# As the caret sign `^` in the ticker of S&P-500 might cause problem in coding, I prefer rename this column before proceeding:

# %%
stock_prices=stock_prices.rename({'^GSPC':'GSPC'}, axis='columns')

# %% [markdown]
# Now, after having the return for three stock and one market index, extracting risk free rate allows us to compute excess return. To access the risk free rate data, we use `Fred API` as we have learned previosly. Please note that there is no single risk free rate, different researchers apply different risk free rate but the common property of these rates is that they are issued by a government, which makes them safe heaven to invest. Here, we select `3-Month Treasury Constant Maturity Rate`, which is short-term T-Bill with relatively low and safe return.

# %% [markdown]
# Practically speaking, risk-free rate is hypothetical term, because even the safest investments carry a very small amount of risk. However, it is not wrong to say that government-issued debt is much safer compared to comporate-issued one. That is being said, the interest rate on a three-month U.S. Treasury bill is useful proxy for the risk-free rate for U.S.-based investors.

# %%
from fredapi import Fred
fred = Fred(api_key='78b14ec6ba46f484b94db43694468bb1')#  my API key

# %%
fred.search('risk free')
# Out:
#                             id realtime_start realtime_end  \
# series id
# DGS10                    DGS10     2021-05-15   2021-05-15
# GS10                      GS10     2021-05-15   2021-05-15
# WGS10YR                WGS10YR     2021-05-15   2021-05-15
# DGS1                      DGS1     2021-05-15   2021-05-15
# DGS5                      DGS5     2021-05-15   2021-05-15
# WGS1YR                  WGS1YR     2021-05-15   2021-05-15
# GS1                        GS1     2021-05-15   2021-05-15
# GS5                        GS5     2021-05-15   2021-05-15
# WGS5YR                  WGS5YR     2021-05-15   2021-05-15
# DGS30                    DGS30     2021-05-15   2021-05-15
# DGS2                      DGS2     2021-05-15   2021-05-15
# GS30                      GS30     2021-05-15   2021-05-15
# WGS30YR                WGS30YR     2021-05-15   2021-05-15
# GS2                        GS2     2021-05-15   2021-05-15
# DGS3MO                  DGS3MO     2021-05-15   2021-05-15
# WGS2YR                  WGS2YR     2021-05-15   2021-05-15
# GS3M                      GS3M     2021-05-15   2021-05-15
# DGS1MO                  DGS1MO     2021-05-15   2021-05-15
# GS1M                      GS1M     2021-05-15   2021-05-15
# DGS20                    DGS20     2021-05-15   2021-05-15
# WGS3MO                  WGS3MO     2021-05-15   2021-05-15
# GS20                      GS20     2021-05-15   2021-05-15
# WGS1MO                  WGS1MO     2021-05-15   2021-05-15
# WGS20YR                WGS20YR     2021-05-15   2021-05-15
# DGS3                      DGS3     2021-05-15   2021-05-15
# GS3                        GS3     2021-05-15   2021-05-15
# WGS3YR                  WGS3YR     2021-05-15   2021-05-15
# DGS7                      DGS7     2021-05-15   2021-05-15
# GS7                        GS7     2021-05-15   2021-05-15
# WGS7YR                  WGS7YR     2021-05-15   2021-05-15
# DGS6MO                  DGS6MO     2021-05-15   2021-05-15
# GS6M                      GS6M     2021-05-15   2021-05-15
# WGS6MO                  WGS6MO     2021-05-15   2021-05-15
# CRESD678FRBCLE  CRESD678FRBCLE     2021-05-15   2021-05-15
# RRESD678FRBCLE  RRESD678FRBCLE     2021-05-15   2021-05-15
#
#                                                             title  \
# series id
# DGS10                     10-Year Treasury Constant Maturity Rate
# GS10                      10-Year Treasury Constant Maturity Rate
# WGS10YR                   10-Year Treasury Constant Maturity Rate
# DGS1                       1-Year Treasury Constant Maturity Rate
# DGS5                       5-Year Treasury Constant Maturity Rate
# GS3M            Averages of business days. For further informa...
# DGS1MO          For further information regarding treasury con...
# GS1M            Averages of business days. For further informa...
# DGS20           For further information regarding treasury con...
# WGS3MO          Averages of business days. For further informa...
# GS20            Averages of business days. For information on ...
# WGS1MO          Averages of business days. For further informa...
# WGS20YR         Averages of business days. For further informa...
# DGS3            For further information regarding treasury con...
# GS3             Averages of business days. For further informa...
# WGS3YR          Averages of business days. For further informa...
# DGS7            For further information regarding treasury con...
# GS7             Averages of business days. For further informa...
# WGS7YR          Averages of business days. For further informa...
# DGS6MO          For further information regarding treasury con...
# GS6M            Averages of business days. For further informa...
# WGS6MO          Averages of business days. For further informa...
# CRESD678FRBCLE  In May of 2016, the source discovered errors i...
# RRESD678FRBCLE  In May of 2016, the source discovered errors i...

# %% [markdown]
# Visualization is quite helpful in understanding what the data looks like. So, as a first step, it is encouraged to plot the data and increase the awareness about it. Below, using line plot, trend of the four individual stock and market index are shown. Accordingly, aside from Apple, all others have tended to move upward despite ups and downs along the way.

# %%
for i, stock in enumerate(stock_prices.columns, start=1):
    sns.set
    plt.figure(figsize=(10, 10))
    plt.subplot(5, 1, i)
    plt.plot(stock_prices[stock])
    plt.title(f"{stock}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Correlation coefficient tells us the extent to which variables are related. `Correlation matrix` is a tool to calculate and visualize the correlation coefficients among the variables of interest. The most striking observation is the correlation coefficient of 76% between Comcast and S&P-500 indicating that there is a high correlation between these two variables. However, it is not the case for AT&T and Verizon whose correlation coefficients with S&P-500 are -52% and 55%, respectively.

# %%
heat_corr=stock_prices.corr()
sns.heatmap(heat_corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# As CAPM requires stock returns, there are various ways to calculate return in Python but `.pct_change()` is one of the most easyto-apply function. Once we calculate the return first row becomes `nan` as return for the first entry cannot be computed.

# %%
returns=stock_prices.pct_change()
returns.dropna(inplace=True)
returns.head()
# Out:
#                 AAPL       IBM      INTC      MSFT      GSPC
# Date
# 2021-01-04 -0.024719 -0.015412 -0.003011 -0.021266 -0.014755
# 2021-01-05  0.012364  0.017751  0.018925  0.000965  0.007083
# 2021-01-06 -0.033662  0.024972  0.009682 -0.025929  0.005710
# 2021-01-07  0.034123 -0.002320  0.021331  0.028457  0.014847
# 2021-01-08  0.008631 -0.003566 -0.010347  0.006093  0.005492

# %% [markdown]
# Let us now convert the 3-month risk-free rate into daily rate. It choose the easy way, which is simply dividing it by number of days in 3 months (90).

# %%
risk_free=fred.get_series('DGS3MO')
risk_free=risk_free['2021-01-01':'2021-04-01']
risk_free=risk_free/90

# %%
risk_free=risk_free.dropna().iloc[:-1]

# %%
plt.plot(risk_free)
plt.xlabel('Date')
plt.ylabel('%')
plt.title('3-Month Treasury Constant Maturity Rate')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# To calculate the excess return, we need to subtract risk free rate from the stock returns. We calculate and stor all excess return in data frame named `returns`.

# %%
stocks=["AAPL","IBM","MSFT","INTC","GSPC"]
for i in stocks:
    returns[f"excess_return_{i}"] = returns[i] - risk_free

# %%
returns.head()
# Out:
#                 AAPL       IBM      INTC      MSFT      GSPC  \
# Date
# 2021-01-04 -0.024719 -0.015412 -0.003011 -0.021266 -0.014755
# 2021-01-05  0.012364  0.017751  0.018925  0.000965  0.007083
# 2021-01-06 -0.033662  0.024972  0.009682 -0.025929  0.005710
# 2021-01-07  0.034123 -0.002320  0.021331  0.028457  0.014847
# 2021-01-08  0.008631 -0.003566 -0.010347  0.006093  0.005492
#
#             excess_return_AAPL  excess_return_IBM  excess_return_MSFT  \
# Date
# 2021-01-04           -0.025719          -0.016412           -0.022266
# 2021-01-05            0.011364           0.016751           -0.000035
# 2021-01-06           -0.034662           0.023972           -0.026929
# 2021-01-07            0.033123          -0.003320            0.027457
# 2021-01-08            0.007742          -0.004455            0.005204
#
#             excess_return_INTC  excess_return_GSPC
# Date
# 2021-01-04           -0.004011           -0.015755
# 2021-01-05            0.017925            0.006083
# 2021-01-06            0.008682            0.004710
# 2021-01-07            0.020331            0.013847
# 2021-01-08           -0.011236            0.004603

# %% [markdown]
# ## Running CAPM

# %% [markdown]
# We are ready to run the CAPM analysis after all these preparation process.

# %%
import statsmodels.api as sm

# %%
y_aapl=returns['excess_return_AAPL']
X=returns['excess_return_GSPC']

# %%
X= sm.add_constant(X, prepend=False)
CAPM_AAPL= sm.OLS(y_aapl, X)
CAPM_results_AAPL = CAPM_AAPL.fit()

# %%
CAPM_results_AAPL.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     excess_return_AAPL   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.432
# Method:                 Least Squares   F-statistic:                     46.73
# Date:                Sat, 15 May 2021   Prob (F-statistic):           5.13e-09
# Time:                        20:34:45   Log-Likelihood:                 167.80
# No. Observations:                  61   AIC:                            -331.6
# Df Residuals:                      59   BIC:                            -327.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     1.3891      0.203      6.836      0.000       0.982       1.796
# const                 -0.0023      0.002     -1.126      0.265      -0.006       0.002
# ==============================================================================
# Omnibus:                        2.777   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.249   Jarque-Bera (JB):                2.142
# Skew:                          -0.174   Prob(JB):                        0.343
# Kurtosis:                       3.849   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_IBM=returns['excess_return_IBM']

# %%
X = sm.add_constant(X, prepend=False)
CAPM_IBM= sm.OLS(y_IBM, X)
CAPM_results_IBM = CAPM_IBM.fit()

# %%
CAPM_results_IBM.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      excess_return_IBM   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     4.187
# Date:                Sat, 15 May 2021   Prob (F-statistic):             0.0452
# Time:                        20:34:45   Log-Likelihood:                 159.59
# No. Observations:                  61   AIC:                            -315.2
# Df Residuals:                      59   BIC:                            -311.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     0.4757      0.232      2.046      0.045       0.010       0.941
# const                  0.0003      0.002      0.151      0.881      -0.004       0.005
# ==============================================================================
# Omnibus:                       62.009   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              531.746
# Skew:                          -2.671   Prob(JB):                    3.41e-116
# Kurtosis:                      16.442   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_MSFT=returns['excess_return_MSFT']

# %%
X = sm.add_constant(X, prepend=False)
CAPM_MSFT= sm.OLS(y_MSFT, X)
CAPM_results_MSFT = CAPM_MSFT.fit()

# %%
CAPM_results_MSFT.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     excess_return_MSFT   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     47.26
# Date:                Sat, 15 May 2021   Prob (F-statistic):           4.41e-09
# Time:                        20:34:45   Log-Likelihood:                 184.67
# No. Observations:                  61   AIC:                            -365.3
# Df Residuals:                      59   BIC:                            -361.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     1.0595      0.154      6.875      0.000       0.751       1.368
# const               8.649e-05      0.002      0.057      0.955      -0.003       0.003
# ==============================================================================
# Omnibus:                        0.098   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.952   Jarque-Bera (JB):                0.160
# Skew:                           0.088   Prob(JB):                        0.923
# Kurtosis:                       2.823   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_INTC=returns['excess_return_INTC']

# %%
X = sm.add_constant(X, prepend=False)
CAPM_INTC= sm.OLS(y_INTC, X)
CAPM_results_INTC = CAPM_INTC.fit()

# %%
CAPM_results_INTC.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     excess_return_INTC   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     36.41
# Date:                Sat, 15 May 2021   Prob (F-statistic):           1.14e-07
# Time:                        20:34:45   Log-Likelihood:                 146.81
# No. Observations:                  61   AIC:                            -289.6
# Df Residuals:                      59   BIC:                            -285.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# excess_return_GSPC     1.7298      0.287      6.034      0.000       1.156       2.304
# const                  0.0032      0.003      1.140      0.259      -0.002       0.009
# ==============================================================================
# Omnibus:                       14.511   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               56.109
# Skew:                          -0.257   Prob(JB):                     6.55e-13
# Kurtosis:                       7.670   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# First, we run the CAPM analysis for `Apple` and it turns out that Apple is more volatile than the S&P-500 as we have a beta coefficient of 1.3845. This estimated beta coefficient is statistically significant at 1% level since we have a t-value of 6.847 (or p-value of 0.0000). However, the intercept term is not statistically significant. Therefore, interpretation of the intercept term, which indicates the performance of the technical analysis, does not make sense.

# %% [markdown]
# When it comes to `IBM`, the result is quite similar in terms of slope coefficien $\beta$ and intercept term. The beta coefficient of 0.4899 implies that there is a correlation between excess market return and excess return of the IBM. More specifically, 1-unit increase in S&P-500 leads to an increase in IBM return by nearly 0.4899. The result also suggests that the IBM is less risky than market index.  Again, the intercept term is not statistically significant at conventional confidence interval.

# %% [markdown]
# `Microsoft` does tell us a similar story with positive and statistically significant beta coefficient and statistically insignificant intercept term. The magnitude of beta coefficient is 1.0577 indicating that 1-unit increase in S&P-500 results in an increase of 1.0577 in Microsoft's return.

# %% [markdown]
# In summary, given the result obtained via CAPM, the most and least risky or volatile stocks are INTEL and IBM, respectively.

# %% [markdown]
# ## Compare the Performance

# %% [markdown]
# CAPM is also a tool for investor to understand whether an asset is fairly priced. To determine that, we need to use $\beta$ that we obtained from CAPM analysis and compare with the investor estimates. The `Security Market Line`(SML) is able to test whether securities are fairly priced or not.

# %% [markdown]
# More elaborately, SML exhibits the linear relationship between expected asset returns and betas obtained from CAPM. All the correctly priced securities are plotted on the SML. If the assets lie above the SML line, the assets are undervalued due to the higher return for a given amount of risk. Conversely, the assets lie below the SML are overvalued because it return of this stock is lower for a given amount of risk.

# %%
import matplotlib.pyplot as plt

# %%
#rf:risk_free rate
#ret:return
#rm: market return
def SML(rf,ret,betas):
    asset_ret = [rf+(rm-rf)*i for i in betas]
    plt.plot(betas,asset_ret)
    plt.xlabel("Asset Beta")
    plt.ylabel("Asset Return")
    plt.title("Security Market Line")
    plt.plot(1,ret,"ro")

# %%
ret_cov=returns.iloc[:,:4].cov()

rm=returns['GSPC'].mean()
risk_free_mean=risk_free.mean()

betas=[CAPM_results_AAPL.params[0],CAPM_results_IBM.params[0],
       CAPM_results_MSFT.params[0],CAPM_results_INTC.params[0]]

# %%
SML(risk_free_mean,rm,betas)

# %% [markdown]
# Given the beta, if the stock locates below the SML, this implies that stock has a lower return per unit of risk assumed. Hence, it can be concluded that the stock is overvalued and decide to sell the stock. Conversely, if the stock locates below the SML, stock has a lower return per unit of risk assumed, which is considered to be undervalued and buying a stock would be wise choice.

# %% [markdown]
# Now suppose that the return expectations for
#
# * Apple is 0.1%
# * IBM is 0.05%
# * Microsoft is 0.025%
# * Intel is 0.09%

# %%
ret_exp=[0.0010,0.005,0.0025,0.0009]
df_ret_exp=pd.DataFrame(ret_exp)
df_betas=pd.DataFrame(betas)
df_all=pd.concat([df_betas,df_ret_exp],axis=1)
df_all.columns=['betas','ret_exp']
df_all.index=returns.columns[:4]

# %%
def over_under_val(rf,rm,stock):
    x = rf+(rm-rf)*df_all['betas'].loc[stock]
    y = df_all['ret_exp'].loc[stock]
    
    if x < y:
        print('The stock is undervalued')
        
    elif x > y:
        print('The stock is overvalued')
        
    else:
        print('The stock is fairly priced')

# %%
over_under_val(risk_free_mean,rm,'INTC')
# Out:
# The stock is undervalued

# %%
market_std=returns['excess_return_GSPC'].std()

# %% [markdown]
# Now, it seem like you obtained  every inputs required to compute the ratios used for gauging the risk-reward combinations. We will do that using the scenarios provided in the instructions. Let me start with the first scenario, which is:
#
# * If portfolio is not well-diversified
#
# In this scenario, we are supposed to use Sharpe ratio in that if an investor holds a portfolio that is not fully diversified, total risk matters and Sharpe ratio consider the total risk. Recall that Sharpe ratio is:
#
# $$Sharpe=\frac{r_i-r_f}{\sigma_i}$$
#
# where $r_i$ and $\sigma_i$ denote return and standard deviation of the stock, respectively.

# %%
def sharpe(stocks,rf,n_assets):
    sharpe_ratios={}
    for i,j in zip(stocks,range(n_assets)):
        sharpe_ratios[i]=(returns.iloc[:,j].mean()-rf)/np.std(returns.iloc[:,j])
    return sharpe_ratios

# %%
stocks=returns.columns[:4]
sharpe_ratios=sharpe(stocks,risk_free_mean,4)
sharpe_ratios
# Out:
# {'AAPL': -0.08247663178592599,
#  'IBM': 0.029469598182172874,
#  'INTC': 0.14162755213693057,
#  'MSFT': 0.03246437796340351}

# %% [markdown]
# The second scenario is:
# * If portfolio is well-diversified
#
# This is an ideal situation for Treynor ratio, because Treynor ratio takes systematic risk into account to assess the risk-reward situation of an asset or a portfolio. In addition to this ratio, Jensen's alpha can be employed as well as it consider the systematic risk.

# %% [markdown]
# $$\text{Treynor ratio}=\frac{r_i-r_f}{\beta_i}$$

# %%
def treynor(stocks,rf,n_assets):
    treynor_ratios={}
    for i, stock in enumerate(stocks):
        treynor_ratios[stock]=(returns.iloc[:,i].mean()-rf)/df_all['betas'][stock]
    return treynor_ratios

# %%
treynor_ratios=treynor(stocks,risk_free_mean,4)
treynor_ratios
# Out:
# {'AAPL': -0.001230846287407356,
#  'IBM': 0.001131663892067636,
#  'INTC': 0.003712409327816563,
#  'MSFT': 0.00029579952666323084}

# %% [markdown]
# Jensen's alpha is really easy to calculate as it is nothing but the the intercept term in the CAPM.

# %%
print(f'Alpha for Apple is {CAPM_results_AAPL.params[1]}')
print(f'Alpha for IBM is {CAPM_results_IBM.params[1]}')
print(f'Alpha for Microsoft is {CAPM_results_MSFT.params[1]}')
print(f'Alpha for Intel is {CAPM_results_INTC.params[1]}')
# Out:
# Alpha for Apple is -0.002267276470866441
# Alpha for IBM is 0.00034741385296169333
# Alpha for Microsoft is 8.648815344203888e-05
# Alpha for Intel is 0.003238862608064364

# %% [markdown]
# Third and the last scenario is:
# * If stock analyst performance matters
#
# Intercept term ($\alpha$) in CAPM analysis reveals the stock analyst performance. So, the answer is Jensen's alpha again. Let's dig into more what happens if $\alpha$ takes on different values:
#
# * Positive alpha: Analyst beats the market and gain profit
# * Zero alpha: Analyst performance replicates the market performance
# * Negative alpha: Poor analyst performance

# %% [markdown]
# It is time to interpret the result. Let's start off with the Sharpe ratio. The higher the Sharpe ratio is, the higher the return we gain per risk is. In this context, we are looking for highest stock with Sharpe ratio, which is `Intel`. It would be a good choice to invest in Microsoft, because we gain more in relative to risk we assumed.

# %%
print(max(sharpe_ratios, key=sharpe_ratios.get))
print(max(sharpe_ratios.values()))
# Out:
# INTC
# 0.14162755213693057

# %% [markdown]
# The `Apple` has the lowest Sharpe ratio indicating that it assumes higher risk per return in relative to other stocks considered.

# %%
print(min(sharpe_ratios, key=sharpe_ratios.get))
print(min(sharpe_ratios.values()))
# Out:
# AAPL
# -0.08247663178592599

# %% [markdown]
# Once we calculate maximum and minimum Treynor ratios, it turns out that the results confirm the one we found via Sharpe ratio. Still, the most and least feasible stocks are Intel and Apple, respectively.

# %%
print(max(treynor_ratios,key=treynor_ratios.get))
print(max(treynor_ratios.values()))
# Out:
# INTC
# 0.003712409327816563

# %%
print(min(treynor_ratios,key=treynor_ratios.get))
print(min(treynor_ratios.values()))
# Out:
# AAPL
# -0.001230846287407356

# %% [markdown]
# As for the interpretation of Jensen's alpha, none of the intercept terms in the CAPM analysis are statistically significant. Therefore, we cannot draw a reliable result from Jensen's alpha. Nevertheless, for the sake of practice, I indicate the alpha values below:

# %% [markdown]
# ##  Arbitrage Pricing Theorem (APT)

# %% [markdown]
# Despite all merits that CAPM have, it is not free from critism some of which are listed above. Stephen Ross 1976 attempted to address these critics and propose `Arbitrage Pricing Theorem` (APT), which is based on the identifying various systematic risk factors, which is rather appealing in that it is not realistic to assume that single systematic risk factor affects stock returns. However, inclusion of sources of macroeconomic variable can provide us a better understanding about the stock returns. So, the main goal of APT is to improve portfolio performance by better understanding portfolio creation and evaluation.

# %% [markdown]
# The Arbitrage Pricing Model was proposed by Stephen Ross and predicts the relationship between the return of the portfolio and the return of a single asset through several independent macroeconomic variables. The APT has following assumptions (Bodie et al.(2008)):

# %% [markdown]
# * Security returns can be described by a factor model;
# * There are sufficient securities to diversify away idiosyncratic risk; and
# * Well-functioning security markets do not allow for the persistence of arbitrage opportunities.

# %% [markdown]
# We can generalize the APT model as follows:

# %% [markdown]
# $$\begin{equation}
# r_i- r_f = \alpha_i + \beta_{im}(r_m-r_f) +...+ \beta_{ij}(r_j-r_f)  + \epsilon_i
# \end{equation}$$

# %% [markdown]
# where
#  * $r_i$: Expected return of the $i^{th}$ stock
#  * $\alpha_i$: asset’s return coming from technical analysis
#  * $r_m$ and $r_j$: common risk factors
#  * $a_{im}$: systematic factor of $m^{th}$ factor
#  * $\epsilon_i$: Error term

# %% [markdown]
# Now, the question is how do we find the proper macroeconomic factors? We are looking for some important risk factor that raise the concern of the investors.

# %% [markdown]
# [Chen, Roll and Ross (1986)]('https://pdfs.semanticscholar.org/08d9/21ea5c119ea770194bce73f726adf5614daa.pdf?_ga=2.9307062.284215294.1589479012-1597751336.1589479012') address this issue by listing following variables:

# %% [markdown]
# * Inflation rate
# * Growth rate in industrial production
# * Term structure
# * Spread between high-grade and low-grade bond
# * Real interest rate
# * Oil prices

# %% [markdown]
# For the sake of practice and to equip yourself with additional information, I suggest you to use another API here. What about using `AlphaVantage`. Alpha Vantage is a data providing company partnered with major exchanges and institutions. Using Alpha Vantage' API, it is possible to access stock prices, stock fundamentals, Forex information and many more with different time interval- e.g. intraday, daily, weekly, an so on. For more information, please see https://www.alphavantage.co/support/#support[Alpha Vantage's website.]

# %% [markdown]
# Let me change the tickers so that we can analyze different companies. This time, let's extract the stock prices of two social media companies, which are:
# * Twitter
# * Facebook

# %% [markdown]
# Having listed some relevant variables, we are now able to run the `APT` analysis. We could proceed by retrieving the data first. Again, we refer to the relate APIs to extract these data. Thanks to `Yahoo Finance` and `FRED`, we have stock prices, risk free rate, and stock market index (S&P-500) from the preceding part.

# %% [markdown]
# Let's import all the necessary libraries first.

# %%
import requests
from io import StringIO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from fredapi import Fred

# %%
def getMonthlyData(symbol):
        parameters = {'function': 'TIME_SERIES_MONTHLY_ADJUSTED', 'symbol': symbol,
                       'outputsize':'full',
                       'datatype': 'csv', 
                       'apikey': 'LL1WA15IW41XV2T2'}

        response = requests.get('https://www.alphavantage.co/query', params=parameters)

        # Process the CSV file retrieved
        csvText = StringIO(response.text)
        data = pd.read_csv(csvText, index_col='timestamp')
        return data

# %% [markdown]
# Before starting, here is a little trick for you. The ticker of the `S&P-500` is `SPY` in Alpha Vantage API.

# %%
tickers= ["TWTR", "FB", "SPY"]
df=[]
for i in tickers:
    df.append(getMonthlyData(i)[::-1]['close']['2015-01-01':'2021-05-01'])
stocks=pd.DataFrame(df).T
stocks.columns=tickers

# %%
stocks.head()
# Out:
#              TWTR      FB     SPY
# timestamp
# 2015-01-30  37.53  75.910  199.45
# 2015-02-27  48.08  78.970  210.66
# 2015-03-31  50.08  82.215  206.43
# 2015-04-30  38.96  78.770  208.46
# 2015-05-29  36.67  79.190  211.14

# %% [markdown]
# As per the article of Chen, Roll and Ross (1986), I want to pick the following three variables:
#
# * Growth rate in industrial production
#
# * Inflation rate
#
# * Stock Index

# %% [markdown]
# These variables will be your independent variables as they have appeared to explain a significant portion of the time-series variability of stock returns.

# %% [markdown]
# At this point, to extract the macroeconomic variable, `FRED API` would be a convenient database:

# %%
fred = Fred(api_key='78b14ec6ba46f484b94db43694468bb1')

# %%
fred.search('industrial')
# Out:
#                       id realtime_start realtime_end  \
# series id
# INDPRO            INDPRO     2021-05-15   2021-05-15
# IPB50001N      IPB50001N     2021-05-15   2021-05-15
# IPB50001SQ    IPB50001SQ     2021-05-15   2021-05-15
# IPB50001NQ    IPB50001NQ     2021-05-15   2021-05-15
# IPMAN              IPMAN     2021-05-15   2021-05-15
# ...                  ...            ...          ...
# IPG3327SQ      IPG3327SQ     2021-05-15   2021-05-15
# IPG3327N        IPG3327N     2021-05-15   2021-05-15
# IPG3327NQ      IPG3327NQ     2021-05-15   2021-05-15
# IPB511222NQ  IPB511222NQ     2021-05-15   2021-05-15
# IPB511222SQ  IPB511222SQ     2021-05-15   2021-05-15
#
#                                                          title  \
# series id
# INDPRO                      Industrial Production: Total Index
# IPB50001N                   Industrial Production: Total Index
# IPB50001SQ                  Industrial Production: Total Index
# IPB50001NQ                  Industrial Production: Total Index
# IPMAN             Industrial Production: Manufacturing (NAICS)
# ...                                                        ...
# IPG3327SQ    Industrial Production: Manufacturing: Durable ...
# IPG3327N     Industrial Production: Manufacturing: Durable ...
# IPG3327NQ    Industrial Production: Manufacturing: Durable ...
# IPB511222NQ  Industrial Production: Durable Consumer Goods:...
# IPB511222SQ  Industrial Production: Durable Consumer Goods:...
#
#             observation_start observation_end  frequency frequency_short  \
# series id
# INDPRO             1919-01-01      2021-04-01    Monthly               M
# IPB50001N          1919-01-01      2021-04-01    Monthly               M
# IPB50001SQ         1919-01-01      2021-01-01  Quarterly               Q
# IPB50001NQ         1919-01-01      2021-01-01  Quarterly               Q
# IPMAN              1972-01-01      2021-04-01    Monthly               M
# ...                       ...             ...        ...             ...
# IPG3327SQ          1972-01-01      2021-01-01  Quarterly               Q
# IPG3327N           1972-01-01      2021-04-01    Monthly               M
# IPG3327NQ          1972-01-01      2021-01-01  Quarterly               Q
# IPB511222NQ        1947-01-01      2021-01-01  Quarterly               Q
# IPB511222SQ        1947-01-01      2021-01-01  Quarterly               Q
#
#                       units     units_short      seasonal_adjustment  \
# series id
# INDPRO       Index 2012=100  Index 2012=100      Seasonally Adjusted
# IPB50001N    Index 2012=100  Index 2012=100  Not Seasonally Adjusted
# IPB50001SQ   Index 2012=100  Index 2012=100      Seasonally Adjusted
# IPB50001NQ   Index 2012=100  Index 2012=100  Not Seasonally Adjusted
# IPMAN        Index 2012=100  Index 2012=100      Seasonally Adjusted
# ...                     ...             ...                      ...
# IPG3327SQ    Index 2012=100  Index 2012=100      Seasonally Adjusted
# IPG3327N     Index 2012=100  Index 2012=100  Not Seasonally Adjusted
# IPG3327NQ    Index 2012=100  Index 2012=100  Not Seasonally Adjusted
# IPB511222NQ  Index 2012=100  Index 2012=100  Not Seasonally Adjusted
# IPB511222SQ  Index 2012=100  Index 2012=100      Seasonally Adjusted
#
#             seasonal_adjustment_short               last_updated popularity  \
# series id
# INDPRO                             SA  2021-05-14 08:19:02-05:00         86
# IPB50001N                         NSA  2021-05-14 08:19:21-05:00         45
# IPB50001SQ                         SA  2021-05-14 08:18:07-05:00         27
# IPB50001NQ                        NSA  2021-05-14 08:18:24-05:00         12
# IPMAN                              SA  2021-05-14 08:18:02-05:00         64
# ...                               ...                        ...        ...
# IPG3327SQ                          SA  2021-05-14 08:22:21-05:00          1
# IPG3327N                          NSA  2021-05-14 08:23:19-05:00          1
# IPG3327NQ                         NSA  2021-05-14 08:22:21-05:00          1
# IPB511222NQ                       NSA  2021-05-14 08:23:00-05:00          1
# IPB511222SQ                        SA  2021-05-14 08:23:00-05:00          1
#
#                                                          notes
# series id
# INDPRO       The Industrial Production Index (INDPRO) is an...
# IPB50001N    The industrial production (IP) index measures ...
# IPB50001SQ   The industrial production (IP) index measures ...
# IPB50001NQ   The industrial production (IP) index measures ...
# IPMAN                                                     None
# ...                                                        ...
# IPG3327SQ    The industrial production (IP) index measures ...
# IPG3327N     The industrial production (IP) index measures ...
# IPG3327NQ    The industrial production (IP) index measures ...
# IPB511222NQ  The industrial production (IP) index measures ...
# IPB511222SQ  The industrial production (IP) index measures ...
#
# [1000 rows x 15 columns]

# %%
ind=fred.get_series('INDPRO')
ind=ind['2015-01-01':'2021-05-01']

# %%
ind.head()
# Out:
# 2015-01-01    105.9806
# 2015-02-01    105.4425
# 2015-03-01    105.1464
# 2015-04-01    104.5272
# 2015-05-01    104.0742
# dtype: float64

# %%
fred.search('potential inflation')
# Out:
#                         id realtime_start realtime_end  \
# series id
# FEDTARMDLR      FEDTARMDLR     2021-05-15   2021-05-15
# GDPC1CTMLR      GDPC1CTMLR     2021-05-15   2021-05-15
# GDPC1MDLR        GDPC1MDLR     2021-05-15   2021-05-15
# UNRATECTMLR    UNRATECTMLR     2021-05-15   2021-05-15
# PCECTPICTLLR  PCECTPICTLLR     2021-05-15   2021-05-15
# PCECTPICTMLR  PCECTPICTMLR     2021-05-15   2021-05-15
# FEDTARCTLLR    FEDTARCTLLR     2021-05-15   2021-05-15
# GDPC1RHLR        GDPC1RHLR     2021-05-15   2021-05-15
# GDPC1RMLR        GDPC1RMLR     2021-05-15   2021-05-15
# PCECTPIRLLR    PCECTPIRLLR     2021-05-15   2021-05-15
# FEDTARRMLR      FEDTARRMLR     2021-05-15   2021-05-15
# UNRATERHLR      UNRATERHLR     2021-05-15   2021-05-15
# PCECTPIMDLR    PCECTPIMDLR     2021-05-15   2021-05-15
# UNRATEMDLR      UNRATEMDLR     2021-05-15   2021-05-15
# UNRATECTHLR    UNRATECTHLR     2021-05-15   2021-05-15
# PCECTPIRHLR    PCECTPIRHLR     2021-05-15   2021-05-15
# PCECTPIRMLR    PCECTPIRMLR     2021-05-15   2021-05-15
# FEDTARCTMLR    FEDTARCTMLR     2021-05-15   2021-05-15
# FEDTARRLLR      FEDTARRLLR     2021-05-15   2021-05-15
# GDPC1CTLLR      GDPC1CTLLR     2021-05-15   2021-05-15
# CPIEAPPAREL         1982-12-01      2021-04-01         Monthly
# CPIECOMEDU          1993-01-01      2021-04-01         Monthly
# CPIEREC             1993-01-01      2021-04-01         Monthly
#
#              frequency_short                                            units  \
# series id
# FEDTARMDLR                NA                                          Percent
# GDPC1CTMLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# GDPC1MDLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATECTMLR               NA                          Fourth Quarter, Percent
# PCECTPICTLLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPICTMLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARCTLLR               NA                                          Percent
# GDPC1RHLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# GDPC1RMLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPIRLLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARRMLR                NA                                          Percent
# UNRATERHLR                NA                          Fourth Quarter, Percent
# PCECTPIMDLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATEMDLR                NA                                          Percent
# UNRATECTHLR               NA                          Fourth Quarter, Percent
# PCECTPIRHLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPIRMLR               NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARCTMLR               NA                                          Percent
# FEDTARRLLR                NA                                          Percent
# GDPC1CTLLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# PCECTPICTHLR              NA  Fourth Quarter to Fourth Quarter Percent Change
# FEDTARRHLR                NA                                          Percent
# FEDTARCTHLR               NA                                          Percent
# UNRATERMLR                NA                          Fourth Quarter, Percent
# GDPC1RLLR                 NA  Fourth Quarter to Fourth Quarter Percent Change
# GDPC1CTHLR                NA  Fourth Quarter to Fourth Quarter Percent Change
# UNRATERLLR                NA                          Fourth Quarter, Percent
# UNRATECTLLR               NA                          Fourth Quarter, Percent
# GDPPOT                     Q                 Billions of Chained 2012 Dollars
# NROU                       Q                                          Percent
# NROUST                     Q                                          Percent
# CPIEHOUSE                  M                                   Index 1982=100
# CPIEALL                    M                                   Index 1982=100
# CPIEMEDCARE                M                                   Index 1982=100
# CPIEBEV                    M                                   Index 1982=100
# CPIEOTRGS                  M                                   Index 1982=100
# CPIETRANS                  M                                   Index 1982=100
# CPIEAPPAREL                M                                   Index 1982=100
# CPIECOMEDU                 M                                   Index 1982=100
# CPIEREC                    M                                   Index 1982=100
#
#                                     units_short      seasonal_adjustment  \
# series id
# FEDTARMDLR                                    %  Not Seasonally Adjusted
# GDPC1CTMLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# GDPC1MDLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATECTMLR                      Fourth Qtr., %  Not Seasonally Adjusted
# PCECTPICTLLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPICTMLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARCTLLR                                   %  Not Seasonally Adjusted
# GDPC1RHLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# GDPC1RMLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPIRLLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARRMLR                                    %  Not Seasonally Adjusted
# UNRATERHLR                       Fourth Qtr., %  Not Seasonally Adjusted
# PCECTPIMDLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATEMDLR                                    %  Not Seasonally Adjusted
# UNRATECTHLR                      Fourth Qtr., %  Not Seasonally Adjusted
# PCECTPIRHLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPIRMLR   Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARCTMLR                                   %  Not Seasonally Adjusted
# FEDTARRLLR                                    %  Not Seasonally Adjusted
# GDPC1CTLLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# PCECTPICTHLR  Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# FEDTARRHLR                                    %  Not Seasonally Adjusted
# FEDTARCTHLR                                   %  Not Seasonally Adjusted
# UNRATERMLR                       Fourth Qtr., %  Not Seasonally Adjusted
# GDPC1RLLR     Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# GDPC1CTHLR    Fourth Qtr. to Fourth Qtr. % Chg.  Not Seasonally Adjusted
# UNRATERLLR                       Fourth Qtr., %  Not Seasonally Adjusted
# UNRATECTLLR                      Fourth Qtr., %  Not Seasonally Adjusted
# GDPPOT                      Bil. of Chn. 2012 $  Not Seasonally Adjusted
# NROU                                          %  Not Seasonally Adjusted
# NROUST                                        %  Not Seasonally Adjusted
# CPIEHOUSE                        Index 1982=100      Seasonally Adjusted
# CPIEALL                          Index 1982=100      Seasonally Adjusted
# CPIEMEDCARE                      Index 1982=100      Seasonally Adjusted
# CPIEBEV                          Index 1982=100      Seasonally Adjusted
# CPIEOTRGS                        Index 1982=100      Seasonally Adjusted
# CPIETRANS                        Index 1982=100      Seasonally Adjusted
# CPIEAPPAREL                      Index 1982=100      Seasonally Adjusted
# CPIECOMEDU                       Index 1982=100      Seasonally Adjusted
# CPIEREC                          Index 1982=100      Seasonally Adjusted
#
#              seasonal_adjustment_short               last_updated popularity  \
# series id
# FEDTARMDLR                         NSA  2021-03-17 15:57:05-05:00         45
# GDPC1CTMLR                         NSA  2021-03-17 15:57:11-05:00         32
# GDPC1MDLR                          NSA  2021-03-17 15:57:20-05:00         28
# UNRATECTMLR                        NSA  2021-03-17 15:57:14-05:00         20
# PCECTPICTLLR                       NSA  2021-03-17 15:57:25-05:00         15
# PCECTPICTMLR                       NSA  2021-03-17 15:57:19-05:00         12
# FEDTARCTLLR                        NSA  2021-03-17 15:57:23-05:00         11
# GDPC1RHLR                          NSA  2021-03-17 15:57:35-05:00          8
# GDPC1RMLR                          NSA  2021-03-17 15:57:28-05:00          7
# PCECTPIRLLR                        NSA  2021-03-17 15:57:22-05:00          6
# FEDTARRMLR                         NSA  2021-03-17 15:57:33-05:00          6
# UNRATERHLR                         NSA  2021-03-17 15:58:03-05:00          6
# PCECTPIMDLR                        NSA  2021-03-17 15:57:29-05:00          5
# UNRATEMDLR                         NSA  2021-03-17 15:57:37-05:00          5
# UNRATECTHLR                        NSA  2021-03-17 15:58:03-05:00          4
# PCECTPIRHLR                        NSA  2021-03-17 15:58:02-05:00          3
# PCECTPIRMLR                        NSA  2021-03-17 15:57:36-05:00          3
# FEDTARCTMLR                        NSA  2021-03-17 15:57:39-05:00          3
# FEDTARRLLR                         NSA  2021-03-17 15:57:51-05:00          3
# GDPC1CTLLR                         NSA  2021-03-17 15:57:41-05:00          3
# PCECTPICTHLR                       NSA  2021-03-17 15:58:01-05:00          2
# FEDTARRHLR                         NSA  2021-03-17 15:57:50-05:00          2
# FEDTARCTHLR                        NSA  2021-03-17 15:57:38-05:00          2
# UNRATERMLR                         NSA  2021-03-17 15:57:45-05:00          2
# GDPC1RLLR                          NSA  2021-03-17 15:57:56-05:00          1
# GDPC1CTHLR                         NSA  2021-03-17 15:57:53-05:00          1
# UNRATERLLR                         NSA  2021-03-17 15:58:04-05:00          1
# UNRATECTLLR                        NSA  2021-03-17 15:58:03-05:00          1
# GDPPOT                             NSA  2021-02-01 14:37:02-06:00         78
# NROU                               NSA  2021-02-01 14:37:05-06:00         78
# NROUST                             NSA  2021-02-01 14:37:07-06:00         59
# CPIEHOUSE                           SA  2021-05-12 15:31:01-05:00         28
# CPIEALL                             SA  2021-05-12 15:31:01-05:00         23
# CPIEMEDCARE                         SA  2021-05-12 15:31:01-05:00         16
# CPIEBEV                             SA  2021-05-12 15:31:02-05:00         16
# CPIEOTRGS                           SA  2021-05-12 15:31:03-05:00         13
# CPIETRANS                           SA  2021-05-12 15:31:02-05:00         10
# CPIEAPPAREL                         SA  2021-05-12 15:31:03-05:00          6
# CPIECOMEDU                          SA  2021-05-12 15:31:02-05:00          5
# CPIEREC                             SA  2021-05-12 15:31:03-05:00          5
#
#                                                           notes
# series id
# FEDTARMDLR    The longer-run projections are the rates of gr...
# GDPC1CTMLR    The longer-run projections are the rates of gr...
# GDPC1MDLR     The longer-run projections are the rates of gr...
# UNRATECTMLR   The longer-run projections are the rates of gr...
# PCECTPICTLLR  The longer-run projections are the rates of gr...
# PCECTPICTMLR  The longer-run projections are the rates of gr...
# FEDTARCTLLR   The longer-run projections are the rates of gr...
# GDPC1RHLR     The longer-run projections are the rates of gr...
# GDPC1RMLR     The longer-run projections are the rates of gr...
# PCECTPIRLLR   The longer-run projections are the rates of gr...
# FEDTARRMLR    The longer-run projections are the rates of gr...
# UNRATERHLR    The longer-run projections are the rates of gr...
# PCECTPIMDLR   The longer-run projections are the rates of gr...
# UNRATEMDLR    The longer-run projections are the rates of gr...
# UNRATECTHLR   The longer-run projections are the rates of gr...
# PCECTPIRHLR   The longer-run projections are the rates of gr...
# PCECTPIRMLR   The longer-run projections are the rates of gr...
# FEDTARCTMLR   The longer-run projections are the rates of gr...
# FEDTARRLLR    The longer-run projections are the rates of gr...
# GDPC1CTLLR    The longer-run projections are the rates of gr...
# PCECTPICTHLR  The longer-run projections are the rates of gr...
# FEDTARRHLR    The longer-run projections are the rates of gr...
# FEDTARCTHLR   The longer-run projections are the rates of gr...
# UNRATERMLR    The longer-run projections are the rates of gr...
# GDPC1RLLR     The longer-run projections are the rates of gr...
# GDPC1CTHLR    The longer-run projections are the rates of gr...
# UNRATERLLR    The longer-run projections are the rates of gr...
# UNRATECTLLR   The longer-run projections are the rates of gr...
# GDPPOT        Real potential GDP is the CBO’s estimate of th...
# NROU          The natural rate of unemployment (NAIRU) is th...
# NROUST        The natural rate of unemployment (NAIRU) is th...
# CPIEHOUSE     The BLS calculates a research price index call...
# CPIEALL       The BLS calculates a research price index call...
# CPIEMEDCARE   The BLS calculates a research price index call...
# CPIEBEV       The BLS calculates a research price index call...
# CPIEOTRGS     The BLS calculates a research price index call...
# CPIETRANS     The BLS calculates a research price index call...
# CPIEAPPAREL   The BLS calculates a research price index call...
# CPIECOMEDU    The BLS calculates a research price index call...
# CPIEREC       The BLS calculates a research price index call...

# %%
inf=fred.get_series('CPIEALL')
inf=inf['2015-01-01':'2021-05-01']

# %% [markdown]
# As you are working with monthly data, it does not make sense to use risk free rate (`DGS3MO`) that you used in CAPM as it is daily rate. So, let's pick a monthly version of it, which is `GS3M`.Finally, you need to have risk free rate in APT analysis, as well. To do that, you can make use of `FRED` again.

# %%
fred.search('risk free')
# Out:
#                             id realtime_start realtime_end  \
# series id
# DGS10                    DGS10     2021-05-15   2021-05-15
# GS10                      GS10     2021-05-15   2021-05-15
# WGS10YR                WGS10YR     2021-05-15   2021-05-15
# DGS1                      DGS1     2021-05-15   2021-05-15
# DGS5                      DGS5     2021-05-15   2021-05-15
# WGS1YR                  WGS1YR     2021-05-15   2021-05-15
# GS1                        GS1     2021-05-15   2021-05-15
# GS5                        GS5     2021-05-15   2021-05-15
# WGS5YR                  WGS5YR     2021-05-15   2021-05-15
# DGS30                    DGS30     2021-05-15   2021-05-15
# DGS2                      DGS2     2021-05-15   2021-05-15
# GS30                      GS30     2021-05-15   2021-05-15
# WGS30YR                WGS30YR     2021-05-15   2021-05-15
# GS2                        GS2     2021-05-15   2021-05-15
# DGS3MO                  DGS3MO     2021-05-15   2021-05-15
# WGS2YR                  WGS2YR     2021-05-15   2021-05-15
# GS3M                      GS3M     2021-05-15   2021-05-15
# DGS1MO                  DGS1MO     2021-05-15   2021-05-15
# GS1M                      GS1M     2021-05-15   2021-05-15
# DGS20                    DGS20     2021-05-15   2021-05-15
# WGS3MO                  WGS3MO     2021-05-15   2021-05-15
# GS20                      GS20     2021-05-15   2021-05-15
# WGS1MO                  WGS1MO     2021-05-15   2021-05-15
# WGS20YR                WGS20YR     2021-05-15   2021-05-15
# DGS3                      DGS3     2021-05-15   2021-05-15
# GS3                        GS3     2021-05-15   2021-05-15
# WGS3YR                  WGS3YR     2021-05-15   2021-05-15
# DGS7                      DGS7     2021-05-15   2021-05-15
# GS7                        GS7     2021-05-15   2021-05-15
# WGS7YR                  WGS7YR     2021-05-15   2021-05-15
# DGS6MO                  DGS6MO     2021-05-15   2021-05-15
# GS6M                      GS6M     2021-05-15   2021-05-15
# WGS6MO                  WGS6MO     2021-05-15   2021-05-15
# CRESD678FRBCLE  CRESD678FRBCLE     2021-05-15   2021-05-15
# RRESD678FRBCLE  RRESD678FRBCLE     2021-05-15   2021-05-15
#
#                                                             title  \
# series id
# DGS10                     10-Year Treasury Constant Maturity Rate
# GS10                      10-Year Treasury Constant Maturity Rate
# WGS10YR                   10-Year Treasury Constant Maturity Rate
# DGS1                       1-Year Treasury Constant Maturity Rate
# DGS5                       5-Year Treasury Constant Maturity Rate
# WGS1YR                     1-Year Treasury Constant Maturity Rate
# GS1                        1-Year Treasury Constant Maturity Rate
# DGS20           For further information regarding treasury con...
# WGS3MO          Averages of business days. For further informa...
# GS20            Averages of business days. For information on ...
# WGS1MO          Averages of business days. For further informa...
# WGS20YR         Averages of business days. For further informa...
# DGS3            For further information regarding treasury con...
# GS3             Averages of business days. For further informa...
# WGS3YR          Averages of business days. For further informa...
# DGS7            For further information regarding treasury con...
# GS7             Averages of business days. For further informa...
# WGS7YR          Averages of business days. For further informa...
# DGS6MO          For further information regarding treasury con...
# GS6M            Averages of business days. For further informa...
# WGS6MO          Averages of business days. For further informa...
# CRESD678FRBCLE  In May of 2016, the source discovered errors i...
# RRESD678FRBCLE  In May of 2016, the source discovered errors i...

# %%
risk_free=fred.get_series('GS1')
risk_free=risk_free['2015-01-01':'2021-05-01']

# %%
stocks.describe()
# Out:
#             TWTR          FB         SPY
# count  76.000000   76.000000   76.000000
# mean   30.779211  165.898816  265.277105
# std    12.348700   57.789566   53.455978
# min    14.620000   75.910000  191.590000
# 25%    19.030000  118.712500  215.362500
# 50%    30.545000  166.745000  264.760000
# 75%    36.497500  193.100000  294.580000
# max    77.060000  325.080000  417.300000

# %% [markdown]
# Well, it seems like we have 76 observations with varying statistics. For instance, aside from market index, mean of `SNAP` and `FB` are the lowest and highest ones, respectively. In parallel to this observation, we expect to have low standard deviation for `SNAP` and high one for `FB`. Yes, this is what we get, the standard deviation of `SNAP` is 14.3. This is also the lowest one among the stocks at our disposal. As for the `FB`, the standard deviation hits 57.7 and implies that it has the most risky asset as standard deviation is a proxy of risk in finance.

# %% [markdown]
# In what follows, as suggested, you need to compute inflation rate, which is nothing but the percentage change of it. Here is how you can do that:

# %%
inf_rate=inf.pct_change().dropna()

# %%
risk_free=risk_free/12

# %% [markdown]
# As you can notice, there is a level difference between stock prices, inflation and industrial production index. To deal with the scaling issue, taking logarithm makes sense:

# %%
log_ind=np.log(ind)

# %%
returns=stocks.pct_change()
returns.dropna(inplace=True)
returns.head()
# Out:
#                 TWTR        FB       SPY
# timestamp
# 2015-02-27  0.281108  0.040311  0.056205
# 2015-03-31  0.041597  0.041092 -0.020080
# 2015-04-30 -0.222045 -0.041902  0.009834
# 2015-05-29 -0.058778  0.005332  0.012856
# 2015-06-30 -0.012272  0.083028 -0.024865

# %% [markdown]
# To be consistent, you need to drop the last two months (April and May) of stock prices and the last month from inflation rate, and industrial production as industrial production index and inflation rate do not have observation at this date.

# %%
print(len(returns))
print(len(log_ind))
print(len(inf_rate))
print(len(risk_free))
# Out:
# 75
# 76
# 75
# 76

# %%
log_ind=log_ind.iloc[1:]
risk_free=risk_free.iloc[1:]

# %%
inf_rate.index=returns.index
log_ind.index=returns.index
risk_free.index=returns.index

# %% [markdown]
# After completing the data collection and cleaning process and now we should combine all these variables into single data frame along the columns. Pandas' `concat` function does this for us and create a single data frame. But there is one more step to go. The indeces of the data should be matched properly. The following code does this for us:

# %%
apt_df=pd.concat([returns,inf_rate,log_ind,risk_free],axis=1)
apt_df.rename(columns = {0:'inf_rate',1:'log_ind',2:'risk_free'}, inplace=True)
apt_df
# Out:
#                 TWTR        FB       SPY  inf_rate   log_ind  risk_free
# timestamp
# 2015-02-27  0.281108  0.040311  0.056205  0.003891  4.658166   0.018333
# 2015-03-31  0.041597  0.041092 -0.020080  0.004887  4.655354   0.020833
# 2015-04-30 -0.222045 -0.041902  0.009834  0.002175  4.649447   0.019167
# 2015-05-29 -0.058778  0.005332  0.012856  0.004177  4.645104   0.020000
# 2015-06-30 -0.012272  0.083028 -0.024865  0.003744  4.641670   0.023333
# ...              ...       ...       ...       ...       ...        ...
# 2020-12-31  0.164266 -0.013756  0.032647  0.001039  4.662736   0.008333
# 2021-01-29 -0.066851 -0.054291 -0.010190  0.004240  4.671344   0.008333
# 2021-02-26  0.525035 -0.002748  0.027806  0.005315  4.635823   0.005833
# 2021-03-31 -0.174280  0.143273  0.041987  0.006228  4.659739   0.006667
# 2021-04-30 -0.132170  0.103725  0.052910  0.006975  4.666385   0.005000
#
# [75 rows x 6 columns]

# %%
heat_corr=apt_df.corr()
sns.heatmap(heat_corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# As expected, stocks and market index are highly correlated and we observe the similar phenemon among macro variables as they show high correlation, too.

# %%
cols=returns.columns
for i in cols:
    returns["excess_return_"+str(i)]=returns[i]-risk_free

# %%
returns.head()
# Out:
#                 TWTR        FB       SPY  excess_return_TWTR  \
# timestamp
# 2015-02-27  0.281108  0.040311  0.056205            0.262775
# 2015-03-31  0.041597  0.041092 -0.020080            0.020764
# 2015-04-30 -0.222045 -0.041902  0.009834           -0.241211
# 2015-05-29 -0.058778  0.005332  0.012856           -0.078778
# 2015-06-30 -0.012272  0.083028 -0.024865           -0.035605
#
#             excess_return_FB  excess_return_SPY
# timestamp
# 2015-02-27          0.021978           0.037871
# 2015-03-31          0.020258          -0.040913
# 2015-04-30         -0.061069          -0.009333
# 2015-05-29         -0.014668          -0.007144
# 2015-06-30          0.059695          -0.048198

# %%
df_merged=pd.concat([returns.iloc[:,3:], apt_df.loc[:,['inf_rate','log_ind']]], axis=1,ignore_index=True)
df_merged.rename(columns={0:'excess_return_TWTR',
                        1:'excess_return_FB',
                        2:'excess_return_SPY',
                        3:'inf_rate',
                        4:'log_ind'},inplace=True)

# %%
df_merged.head()
# Out:
#             excess_return_TWTR  excess_return_FB  excess_return_SPY  inf_rate  \
# timestamp
# 2015-02-27            0.262775          0.021978           0.037871  0.003891
# 2015-03-31            0.020764          0.020258          -0.040913  0.004887
# 2015-04-30           -0.241211         -0.061069          -0.009333  0.002175
# 2015-05-29           -0.078778         -0.014668          -0.007144  0.004177
# 2015-06-30           -0.035605          0.059695          -0.048198  0.003744
#
#              log_ind
# timestamp
# 2015-02-27  4.658166
# 2015-03-31  4.655354
# 2015-04-30  4.649447
# 2015-05-29  4.645104
# 2015-06-30  4.641670

# %% [markdown]
# ## Running APT

# %% [markdown]
# As we did before, assigning new variable to dependent and independent variables faciliates the regression analysis. `excess_return_TWTR` is our dependent variable and it is labeled as y by convention. The rest of the variables are independent variables and they are labeled as `X_TWTR`:

# %%
y=df_merged['excess_return_TWTR']
X_TWTR=df_merged.iloc[:,2:]

# %%
X_TWTR= sm.add_constant(X_TWTR, prepend=False)
APT_TWTR= sm.OLS(y, X_TWTR)
APT_results_TWTR = APT_TWTR.fit()

# %%
APT_results_TWTR.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     excess_return_TWTR   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     7.908
# Date:                Sat, 15 May 2021   Prob (F-statistic):           0.000127
# Time:                        15:09:41   Log-Likelihood:                 40.621
# No. Observations:                  75   AIC:                            -73.24
# Df Residuals:                      71   BIC:                            -63.97
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# excess_return_SPY     0.6935      0.276      2.509      0.014       0.142       1.245
# inf_rate             10.5900      7.563      1.400      0.166      -4.490      25.670
# log_ind              -0.5722      0.675     -0.847      0.400      -1.918       0.774
# const                 2.6241      3.123      0.840      0.404      -3.602       8.850
# ==============================================================================
# Omnibus:                        3.081   Durbin-Watson:                   2.384
# Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.337
# Skew:                           0.303   Prob(JB):                        0.311
# Kurtosis:                       3.617   Cond. No.                     2.17e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The findings suggest that the only statistically significant variable is market index `excess_return_SPY`, which has a coefficient of 0.6935 indicating a high correlation with dependent variable. Inflation rate and industrial production seem to have no explanatory power.

# %% [markdown]
# The same procedure is applied to `FB` given below:

# %%
y=df_merged['excess_return_FB']
X_FB=df_merged.iloc[:,2:]

# %%
X_FB= sm.add_constant(X_FB, prepend=False)
APT_FB= sm.OLS(y,X_FB)
APT_results_FB= APT_FB.fit()

# %%
APT_results_FB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       excess_return_FB   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     70.38
# Date:                Sat, 15 May 2021   Prob (F-statistic):           3.16e-21
# Time:                        15:09:41   Log-Likelihood:                 108.25
# No. Observations:                  75   AIC:                            -208.5
# Df Residuals:                      71   BIC:                            -199.2
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# excess_return_SPY     1.0100      0.112      9.002      0.000       0.786       1.234
# inf_rate              4.8534      3.069      1.581      0.118      -1.267      10.974
# log_ind              -0.3202      0.274     -1.169      0.246      -0.867       0.226
# const                 1.4941      1.267      1.179      0.242      -1.033       4.021
# ==============================================================================
# Omnibus:                        3.565   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.168   Jarque-Bera (JB):                3.026
# Skew:                           0.275   Prob(JB):                        0.220
# Kurtosis:                       3.816   Cond. No.                     2.17e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Similar to our findings in Twitter, we have single statistically significant variable,`excess_return_SPY`. Its estimated coefficient is 1.01 showing even higher correlation with dependent variable. However, inflation rate and industrial production are again not statisticall significant, so it makes no sense to interpret the estimated coefficients of these variables.

# %%
def SML(risk_free,ret,betas):
    asset_ret = [risk_free+(rm-risk_free)*i for i in betas]
    plt.plot(betas,asset_ret)
    plt.xlabel("Asset Beta")
    plt.ylabel("Asset Return")
    plt.title("Security Market Line")
    plt.plot(1,ret,"ro")

# %%
ret_cov=returns.iloc[:,:2].cov()
rm=returns['SPY'].mean()
risk_free=risk_free.mean()
betas=[APT_results_TWTR.params[0],APT_results_FB.params[0]]

# %%
SML(risk_free,rm,betas)

# %% [markdown]
# Well, contrary to the theory, the slope of SML is negative implying that the more systematic risk you have, the lower the expected return is. This sounds awkward, but it happens from time to time.

# %% [markdown]
# The negative market risk premium maybe a result of an economic recession or crises in the sample period, and this led us to have a either negative beta or market premium.
